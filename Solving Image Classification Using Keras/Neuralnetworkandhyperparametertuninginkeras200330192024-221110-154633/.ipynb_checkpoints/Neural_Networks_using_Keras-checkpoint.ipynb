# %% [markdown]
# # Steps to solve Emergency vs Non-Emergency vehicle classification problem
#
# <ol>1. Loading the dataset</ol>
# <ol>2. Pre-processing the data</ol>
# <ol>3. Creating training and validation set</ol>
# <ol>4. Defining the model architecture</ol>
# <ol>5. Compiling the model</ol>
# <ol>6. Training the model</ol>
# <ol>7. Evaluating model performance</ol>

# %% [markdown]
# ## 1. Loading the dataset

# %%
# import necessary libraries and functions
import numpy as np
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.layers import Dense, InputLayer
from keras.models import Sequential

from sklearn.model_selection import train_test_split

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !unzip /content/drive/MyDrive/AV/Course_Handouts_Fundamentals_of_Deep_Learning/Dataset.zip

# %%
# reading the csv file
data = pd.read_csv('Dataset/emergency_classification.csv')

# %%
# create random number generator
seed = 42
rng = np.random.RandomState(seed)

# %%
# looking at first five rows of the data
data.head()
# Out:
#   image_names  emergency_or_not
# 0       0.jpg                 1
# 1       1.jpg                 1
# 2       2.jpg                 1
# 3       3.jpg                 1
# 4       4.jpg                 1

# %%
# distribution of classes in the dataset
data['emergency_or_not'].value_counts()
# Out:
# emergency_or_not
# 0    1361
# 1     991
# Name: count, dtype: int64

# %%
# load images and store it in numpy array

# empty list to store the images
X = []
# iterating over each image
for img_name in data.image_names:
    # loading the image using its name
    img = plt.imread('Dataset/images/' + img_name)
    # saving each image in the list
    X.append(img)
    
# converting the list of images into array
X=np.array(X)

# storing the target variable in separate variable
y = data.emergency_or_not.values

# %%
# shape of the image
X.shape

# %%
# visualizing images
fig,ax = plt.subplots(nrows=1,ncols=5,figsize=(20,20))
for i in range(5):
    ax[i].imshow(X[i*400])
    ax[i].axis('off')

# %% [markdown]
# ## 2. Pre-processing the data

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1qrMvsKOgTmo4Zt93r8G84Z5I_2IfVduq)

# %%
# converting 3 dimensional image to 1 dimensional image
X = X.reshape(X.shape[0], 224*224*3)
X.shape
# Out:
# (2352, 150528)

# %%
# minimum and maximum pixel values of images
X.min(), X.max()
# Out:
# (0, 255)

# %%
# normalizing the pixel values
X = X / X.max()

# %%
# minimum and maximum pixel values of images after normalizing
X.min(), X.max()
# Out:
# (0.0, 1.0)

# %% [markdown]
# ## 3. Creating training and validation set

# %%
# creating a training and validation set
X_train, X_valid, y_train, y_valid=train_test_split(X,y,test_size=0.3, random_state=seed)

# %%
# shape of training and validation set
(X_train.shape, y_train.shape), (X_valid.shape, y_valid.shape)
# Out:
# (((1646, 150528), (1646,)), ((706, 150528), (706,)))

# %% [markdown]
# ## 4. Defining the model architecture

# %%
# defining the architecture of the model
model=Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
# summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               15052900
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 15,053,001
# Trainable params: 15,053,001
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 5. Compiling the model

# %%
# compiling the model
model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])

# %% [markdown]
# ## 6. Training the model

# %%
# training the model
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 4s 114ms/step - loss: 0.7500 - accuracy: 0.5522 - val_loss: 0.6617 - val_accuracy: 0.5708
# Epoch 2/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.6531 - accuracy: 0.6160 - val_loss: 0.6331 - val_accuracy: 0.6374
# Epoch 3/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.6307 - accuracy: 0.6422 - val_loss: 0.7212 - val_accuracy: 0.5680
# Epoch 4/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.6323 - accuracy: 0.6586 - val_loss: 0.6096 - val_accuracy: 0.6742
# Epoch 5/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.6103 - accuracy: 0.6774 - val_loss: 0.5910 - val_accuracy: 0.6884
# Epoch 6/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.6008 - accuracy: 0.6804 - val_loss: 0.6616 - val_accuracy: 0.6020
# Epoch 7/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.5934 - accuracy: 0.6780 - val_loss: 0.5936 - val_accuracy: 0.6728
# Epoch 8/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.6145 - accuracy: 0.6652 - val_loss: 0.5849 - val_accuracy: 0.6912
# Epoch 9/50
# 13/13 [==============================] - 1s 61ms/step - loss: 0.5638 - accuracy: 0.7248 - val_loss: 0.5675 - val_accuracy: 0.6926
# Epoch 10/50
# 13/13 [==============================] - 1s 61ms/step - loss: 0.6094 - accuracy: 0.6932 - val_loss: 0.5738 - val_accuracy: 0.6941
# Epoch 11/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.5696 - accuracy: 0.7060 - val_loss: 0.6281 - val_accuracy: 0.6402
# Epoch 12/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.5368 - accuracy: 0.7418 - val_loss: 0.5920 - val_accuracy: 0.6926
# Epoch 13/50
# 13/13 [==============================] - 1s 61ms/step - loss: 0.5921 - accuracy: 0.6768 - val_loss: 0.5912 - val_accuracy: 0.6771
# Epoch 14/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.5558 - accuracy: 0.7272 - val_loss: 0.5615 - val_accuracy: 0.6926
# Epoch 15/50
# 13/13 [==============================] - 1s 61ms/step - loss: 0.5515 - accuracy: 0.7242 - val_loss: 0.6112 - val_accuracy: 0.6785
# Epoch 16/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.5561 - accuracy: 0.7114 - val_loss: 0.5996 - val_accuracy: 0.6756
# Epoch 17/50
# 13/13 [==============================] - 1s 64ms/step - loss: 0.5684 - accuracy: 0.7090 - val_loss: 0.5956 - val_accuracy: 0.6827
# Epoch 18/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.5458 - accuracy: 0.7242 - val_loss: 0.5571 - val_accuracy: 0.7025
# Epoch 19/50
# Epoch 39/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.4781 - accuracy: 0.7740 - val_loss: 0.5380 - val_accuracy: 0.7153
# Epoch 40/50
# 13/13 [==============================] - 1s 64ms/step - loss: 0.4965 - accuracy: 0.7655 - val_loss: 0.5362 - val_accuracy: 0.7195
# Epoch 41/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.4981 - accuracy: 0.7594 - val_loss: 0.5678 - val_accuracy: 0.7040
# Epoch 42/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.4910 - accuracy: 0.7588 - val_loss: 0.5383 - val_accuracy: 0.7096
# Epoch 43/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.4918 - accuracy: 0.7600 - val_loss: 0.5880 - val_accuracy: 0.6969
# Epoch 44/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.4698 - accuracy: 0.7849 - val_loss: 0.8252 - val_accuracy: 0.6006
# Epoch 45/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.4653 - accuracy: 0.7928 - val_loss: 0.5352 - val_accuracy: 0.7195
# Epoch 46/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.4420 - accuracy: 0.7934 - val_loss: 0.6408 - val_accuracy: 0.6671
# Epoch 47/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.4631 - accuracy: 0.7934 - val_loss: 0.5384 - val_accuracy: 0.7195
# Epoch 48/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.4697 - accuracy: 0.7776 - val_loss: 0.5758 - val_accuracy: 0.7040
# Epoch 49/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.4538 - accuracy: 0.7947 - val_loss: 0.5444 - val_accuracy: 0.7068
# Epoch 50/50
# 13/13 [==============================] - 1s 61ms/step - loss: 0.4592 - accuracy: 0.7697 - val_loss: 0.5489 - val_accuracy: 0.7266

# %% [markdown]
# ## 7. Evaluating model performance

# %%
# getting predictions in the form of class as well as probabilities

predictions = model.predict(X_valid)[:, 0]
# Out:
# 23/23 [==============================] - 0s 11ms/step

# %%
prediction = predictions.reshape(-1,)

# converting probabilities to classes
prediction_int = prediction >= 0.5
prediction_int = prediction_int.astype(np.int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """

# %%
# accuracy on validation set
from sklearn.metrics import accuracy_score
print('Accuracy on validation set:', accuracy_score(y_valid, prediction_int), '%')
# Out:
# Accuracy on validation set: 0.6303116147308782 %

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# pull out the original images from the data which correspond to the validation data
_, valid_vehicles, _, valid_y = train_test_split(data.image_names.values, y, test_size=0.3, random_state=seed)

# get a random index to plot image randomly
index = rng.choice(range(len(valid_vehicles)))

# get the corresponding image name and probability
img_name = valid_vehicles[index]
prob = (predictions * 100).astype(int)[index]

# read the image
img = plt.imread('Dataset/images/' + img_name)

# print probability and actual class
print('Model is', prob , '% sure that it is emergency')
print('And actual class is ', valid_y[index])

# plot image
plt.imshow(img)
# Out:
# Model is 70 % sure that it is emergency
# And actual class is  1

# %% [markdown]
# # Hyperparameter tuning of neural networks

# %% [markdown]
# <ol>1. change activation function of hidden layer</ol>
# <ol>2. increase hidden neurons</ol>
# <ol>3. increase hidden layers</ol>
# <ol>4. increase number of epochs</ol>
# <ol>5. change optimizer</ol>

# %% [markdown]
# ### 1. Changing activation function of hidden layer

# %%
# using relu as activation function in hidden layer
model=Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(100, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# compiling the model
model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])

# %%
# summary of the model
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 100)               15052900
#
#  dense_6 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 15,053,001
# Trainable params: 15,053,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
# training the model for 50 epochs
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 2s 134ms/step - loss: 1.4517 - accuracy: 0.5784 - val_loss: 0.6911 - val_accuracy: 0.5779
# Epoch 2/50
# 13/13 [==============================] - 1s 59ms/step - loss: 0.6605 - accuracy: 0.5923 - val_loss: 0.6808 - val_accuracy: 0.5609
# Epoch 3/50
# 13/13 [==============================] - 1s 61ms/step - loss: 0.6524 - accuracy: 0.6209 - val_loss: 0.7215 - val_accuracy: 0.4660
# Epoch 4/50
# 13/13 [==============================] - 1s 61ms/step - loss: 0.6447 - accuracy: 0.6069 - val_loss: 0.6218 - val_accuracy: 0.6771
# Epoch 5/50
# 13/13 [==============================] - 1s 59ms/step - loss: 0.6348 - accuracy: 0.6549 - val_loss: 0.6076 - val_accuracy: 0.6827
# Epoch 6/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.6572 - accuracy: 0.6446 - val_loss: 0.6123 - val_accuracy: 0.6742
# Epoch 7/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.5945 - accuracy: 0.7029 - val_loss: 0.6275 - val_accuracy: 0.6331
# Epoch 8/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.6121 - accuracy: 0.6665 - val_loss: 0.7204 - val_accuracy: 0.5793
# Epoch 9/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.5938 - accuracy: 0.6920 - val_loss: 0.5950 - val_accuracy: 0.6728
# Epoch 10/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.6155 - accuracy: 0.6750 - val_loss: 0.5945 - val_accuracy: 0.6884
# Epoch 11/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.6036 - accuracy: 0.6756 - val_loss: 0.6023 - val_accuracy: 0.6742
# Epoch 12/50
# 13/13 [==============================] - 1s 73ms/step - loss: 0.5842 - accuracy: 0.7011 - val_loss: 0.6399 - val_accuracy: 0.6133
# Epoch 13/50
# 13/13 [==============================] - 1s 74ms/step - loss: 0.5788 - accuracy: 0.6956 - val_loss: 0.5689 - val_accuracy: 0.7054
# Epoch 34/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.4878 - accuracy: 0.7618 - val_loss: 0.5332 - val_accuracy: 0.7238
# Epoch 35/50
# 13/13 [==============================] - 1s 59ms/step - loss: 0.4749 - accuracy: 0.7728 - val_loss: 0.6651 - val_accuracy: 0.6501
# Epoch 36/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.5161 - accuracy: 0.7448 - val_loss: 0.6098 - val_accuracy: 0.6586
# Epoch 37/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.5299 - accuracy: 0.7351 - val_loss: 0.6389 - val_accuracy: 0.6657
# Epoch 38/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.4743 - accuracy: 0.7770 - val_loss: 0.5313 - val_accuracy: 0.7224
# Epoch 39/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.5017 - accuracy: 0.7412 - val_loss: 0.5649 - val_accuracy: 0.7195
# Epoch 40/50
# 13/13 [==============================] - 1s 59ms/step - loss: 0.4878 - accuracy: 0.7661 - val_loss: 0.5424 - val_accuracy: 0.7167
# Epoch 41/50
# 13/13 [==============================] - 1s 59ms/step - loss: 0.4728 - accuracy: 0.7673 - val_loss: 0.6130 - val_accuracy: 0.7025
# Epoch 42/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.4870 - accuracy: 0.7740 - val_loss: 0.6579 - val_accuracy: 0.5411
# Epoch 43/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.5334 - accuracy: 0.7296 - val_loss: 0.5586 - val_accuracy: 0.7096
# Epoch 44/50
# 13/13 [==============================] - 1s 59ms/step - loss: 0.6027 - accuracy: 0.6640 - val_loss: 0.6356 - val_accuracy: 0.5963
# Epoch 45/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.5523 - accuracy: 0.7011 - val_loss: 0.5811 - val_accuracy: 0.7054
# Epoch 46/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.4841 - accuracy: 0.7618 - val_loss: 0.5902 - val_accuracy: 0.7025
# Epoch 47/50
# 13/13 [==============================] - 1s 59ms/step - loss: 0.4804 - accuracy: 0.7509 - val_loss: 0.5681 - val_accuracy: 0.7040
# Epoch 48/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.4737 - accuracy: 0.7710 - val_loss: 0.8245 - val_accuracy: 0.5765
# Epoch 49/50
# 13/13 [==============================] - 1s 61ms/step - loss: 0.5124 - accuracy: 0.7497 - val_loss: 0.5560 - val_accuracy: 0.7082
# Epoch 50/50
# 13/13 [==============================] - 1s 58ms/step - loss: 0.4809 - accuracy: 0.7618 - val_loss: 0.6229 - val_accuracy: 0.6870

# %%
# getting predictions in the form of class as well as probabilities

predictions = model.predict(X_valid)[:, 0]
prediction = predictions.reshape(-1,)

# converting probabilities to classes
prediction_int = prediction >= 0.5
prediction_int = prediction_int.astype(np.int)
# Out:
# 23/23 [==============================] - 0s 11ms/step
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# accuracy on validation set
print('Accuracy on validation set:', accuracy_score(y_valid,prediction_int), '%')
# Out:
# Accuracy on validation set: 0.6869688385269122 %

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### 2. Increasing hidden neurons

# %%
# increase hidden neurons
model=Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(1024, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

# compiling the model
model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])

# %%
# model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1024)              154141696
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 154,142,721
# Trainable params: 154,142,721
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 4s 143ms/step - loss: 1.5253 - accuracy: 0.5176 - val_loss: 0.7579 - val_accuracy: 0.5623
# Epoch 2/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.7061 - accuracy: 0.5820 - val_loss: 0.6549 - val_accuracy: 0.5921
# Epoch 3/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.6289 - accuracy: 0.6434 - val_loss: 0.6641 - val_accuracy: 0.5836
# Epoch 4/50
# 13/13 [==============================] - 1s 83ms/step - loss: 0.6155 - accuracy: 0.6665 - val_loss: 0.6292 - val_accuracy: 0.6317
# Epoch 5/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.6280 - accuracy: 0.6598 - val_loss: 0.7383 - val_accuracy: 0.5722
# Epoch 6/50
# 13/13 [==============================] - 1s 101ms/step - loss: 0.6708 - accuracy: 0.6130 - val_loss: 0.5897 - val_accuracy: 0.6955
# Epoch 7/50
# 13/13 [==============================] - 1s 109ms/step - loss: 0.5931 - accuracy: 0.6938 - val_loss: 0.5839 - val_accuracy: 0.6898
# Epoch 8/50
# 13/13 [==============================] - 2s 133ms/step - loss: 0.5850 - accuracy: 0.7090 - val_loss: 0.5953 - val_accuracy: 0.6785
# Epoch 9/50
# 13/13 [==============================] - 2s 148ms/step - loss: 0.6505 - accuracy: 0.6282 - val_loss: 0.6076 - val_accuracy: 0.6572
# Epoch 10/50
# 13/13 [==============================] - 1s 98ms/step - loss: 0.5744 - accuracy: 0.7120 - val_loss: 0.5859 - val_accuracy: 0.6926
# Epoch 11/50
# 13/13 [==============================] - 1s 83ms/step - loss: 0.6404 - accuracy: 0.6458 - val_loss: 0.5999 - val_accuracy: 0.6714
# Epoch 12/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.5534 - accuracy: 0.7266 - val_loss: 0.5701 - val_accuracy: 0.6941
# Epoch 13/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.6040 - accuracy: 0.6792 - val_loss: 0.5662 - val_accuracy: 0.6969
# Epoch 14/50
# 13/13 [==============================] - 1s 84ms/step - loss: 0.6112 - accuracy: 0.6689 - val_loss: 0.5654 - val_accuracy: 0.7025
# Epoch 15/50
# 13/13 [==============================] - 1s 98ms/step - loss: 0.5685 - accuracy: 0.7078 - val_loss: 0.5650 - val_accuracy: 0.7096
# Epoch 36/50
# 13/13 [==============================] - 1s 117ms/step - loss: 0.5317 - accuracy: 0.7339 - val_loss: 0.5440 - val_accuracy: 0.7096
# Epoch 37/50
# 13/13 [==============================] - 1s 96ms/step - loss: 0.4946 - accuracy: 0.7515 - val_loss: 0.6900 - val_accuracy: 0.6374
# Epoch 38/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.5327 - accuracy: 0.7254 - val_loss: 0.5841 - val_accuracy: 0.7096
# Epoch 39/50
# 13/13 [==============================] - 1s 83ms/step - loss: 0.5711 - accuracy: 0.6968 - val_loss: 0.5873 - val_accuracy: 0.6884
# Epoch 40/50
# 13/13 [==============================] - 1s 95ms/step - loss: 0.4806 - accuracy: 0.7807 - val_loss: 0.5356 - val_accuracy: 0.7054
# Epoch 41/50
# 13/13 [==============================] - 1s 108ms/step - loss: 0.5313 - accuracy: 0.7388 - val_loss: 0.6060 - val_accuracy: 0.6841
# Epoch 42/50
# 13/13 [==============================] - 1s 97ms/step - loss: 0.4768 - accuracy: 0.7801 - val_loss: 0.5355 - val_accuracy: 0.7054
# Epoch 43/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.5402 - accuracy: 0.7254 - val_loss: 0.6230 - val_accuracy: 0.6657
# Epoch 44/50
# 13/13 [==============================] - 1s 83ms/step - loss: 0.4468 - accuracy: 0.8068 - val_loss: 0.5886 - val_accuracy: 0.6813
# Epoch 45/50
# 13/13 [==============================] - 1s 83ms/step - loss: 0.5687 - accuracy: 0.7126 - val_loss: 0.5459 - val_accuracy: 0.7167
# Epoch 46/50
# 13/13 [==============================] - 1s 93ms/step - loss: 0.4640 - accuracy: 0.7892 - val_loss: 0.5553 - val_accuracy: 0.7110
# Epoch 47/50
# 13/13 [==============================] - 1s 99ms/step - loss: 0.4652 - accuracy: 0.7813 - val_loss: 0.6998 - val_accuracy: 0.6388
# Epoch 48/50
# 13/13 [==============================] - 1s 104ms/step - loss: 0.4915 - accuracy: 0.7533 - val_loss: 0.5388 - val_accuracy: 0.7181
# Epoch 49/50
# 13/13 [==============================] - 1s 97ms/step - loss: 0.4870 - accuracy: 0.7582 - val_loss: 0.7115 - val_accuracy: 0.6360
# Epoch 50/50
# 13/13 [==============================] - 1s 93ms/step - loss: 0.4859 - accuracy: 0.7625 - val_loss: 0.7022 - val_accuracy: 0.6303

# %%
# getting predictions in the form of class as well as probabilities

predictions = model.predict(X_valid)[:, 0]
prediction = predictions.reshape(-1,)

# converting probabilities to classes
prediction_int = prediction >= 0.5
prediction_int = prediction_int.astype(np.int)
# Out:
# 23/23 [==============================] - 0s 13ms/step
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# accuracy on validation set
print('Accuracy on validation set:', accuracy_score(y_valid, prediction_int), '%')
# Out:
# Accuracy on validation set: 0.6303116147308782 %

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### 3. Increasing hidden layers

# %%
# increase hidden layers
model=Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

# compiling the model
model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])

# %%
# model summary
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 100)               15052900
#
#  dense_3 (Dense)             (None, 100)               10100
#
#  dense_4 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 15,063,101
# Trainable params: 15,063,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 3s 169ms/step - loss: 0.6851 - accuracy: 0.5565 - val_loss: 0.6759 - val_accuracy: 0.5609
# Epoch 2/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.6642 - accuracy: 0.5954 - val_loss: 0.6674 - val_accuracy: 0.5637
# Epoch 3/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.6527 - accuracy: 0.6142 - val_loss: 0.6511 - val_accuracy: 0.6586
# Epoch 4/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.6453 - accuracy: 0.6507 - val_loss: 0.6446 - val_accuracy: 0.6388
# Epoch 5/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.6389 - accuracy: 0.6464 - val_loss: 0.6369 - val_accuracy: 0.6615
# Epoch 6/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.6333 - accuracy: 0.6683 - val_loss: 0.6326 - val_accuracy: 0.6586
# Epoch 7/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.6280 - accuracy: 0.6640 - val_loss: 0.6284 - val_accuracy: 0.6601
# Epoch 8/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.6213 - accuracy: 0.6731 - val_loss: 0.6242 - val_accuracy: 0.6785
# Epoch 9/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.6199 - accuracy: 0.6768 - val_loss: 0.6203 - val_accuracy: 0.6700
# Epoch 10/50
# 13/13 [==============================] - 1s 59ms/step - loss: 0.6162 - accuracy: 0.6780 - val_loss: 0.6172 - val_accuracy: 0.6771
# Epoch 11/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.6123 - accuracy: 0.6817 - val_loss: 0.6187 - val_accuracy: 0.6728
# Epoch 12/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.6080 - accuracy: 0.6938 - val_loss: 0.6218 - val_accuracy: 0.6657
# Epoch 13/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.6048 - accuracy: 0.6993 - val_loss: 0.6116 - val_accuracy: 0.6686
# Epoch 14/50
# 13/13 [==============================] - 1s 61ms/step - loss: 0.6031 - accuracy: 0.6944 - val_loss: 0.6064 - val_accuracy: 0.6898
# Epoch 15/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.5984 - accuracy: 0.7066 - val_loss: 0.6107 - val_accuracy: 0.6643
# Epoch 16/50
# Epoch 36/50
# 13/13 [==============================] - 1s 76ms/step - loss: 0.5455 - accuracy: 0.7491 - val_loss: 0.5720 - val_accuracy: 0.7040
# Epoch 37/50
# 13/13 [==============================] - 1s 114ms/step - loss: 0.5442 - accuracy: 0.7527 - val_loss: 0.5719 - val_accuracy: 0.6983
# Epoch 38/50
# 13/13 [==============================] - 1s 81ms/step - loss: 0.5426 - accuracy: 0.7564 - val_loss: 0.5682 - val_accuracy: 0.7025
# Epoch 39/50
# 13/13 [==============================] - 1s 116ms/step - loss: 0.5388 - accuracy: 0.7564 - val_loss: 0.5695 - val_accuracy: 0.7054
# Epoch 40/50
# 13/13 [==============================] - 1s 101ms/step - loss: 0.5403 - accuracy: 0.7418 - val_loss: 0.5772 - val_accuracy: 0.6955
# Epoch 41/50
# 13/13 [==============================] - 1s 98ms/step - loss: 0.5368 - accuracy: 0.7612 - val_loss: 0.5663 - val_accuracy: 0.7011
# Epoch 42/50
# 13/13 [==============================] - 1s 86ms/step - loss: 0.5338 - accuracy: 0.7679 - val_loss: 0.5746 - val_accuracy: 0.6969
# Epoch 43/50
# 13/13 [==============================] - 1s 84ms/step - loss: 0.5331 - accuracy: 0.7570 - val_loss: 0.5657 - val_accuracy: 0.7068
# Epoch 44/50
# 13/13 [==============================] - 1s 77ms/step - loss: 0.5291 - accuracy: 0.7606 - val_loss: 0.5630 - val_accuracy: 0.7054
# Epoch 45/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.5277 - accuracy: 0.7643 - val_loss: 0.5662 - val_accuracy: 0.7040
# Epoch 46/50
# 13/13 [==============================] - 1s 75ms/step - loss: 0.5261 - accuracy: 0.7594 - val_loss: 0.5629 - val_accuracy: 0.7054
# Epoch 47/50
# 13/13 [==============================] - 1s 105ms/step - loss: 0.5244 - accuracy: 0.7649 - val_loss: 0.5693 - val_accuracy: 0.6941
# Epoch 48/50
# 13/13 [==============================] - 1s 101ms/step - loss: 0.5208 - accuracy: 0.7673 - val_loss: 0.5685 - val_accuracy: 0.6926
# Epoch 49/50
# 13/13 [==============================] - 1s 87ms/step - loss: 0.5212 - accuracy: 0.7649 - val_loss: 0.5704 - val_accuracy: 0.6955
# Epoch 50/50
# 13/13 [==============================] - 1s 84ms/step - loss: 0.5184 - accuracy: 0.7746 - val_loss: 0.5717 - val_accuracy: 0.6941

# %%
# getting predictions in the form of class as well as probabilities

predictions = model.predict(X_valid)[:, 0]
prediction = predictions.reshape(-1,)

# converting probabilities to classes
prediction_int = prediction >= 0.5
prediction_int = prediction_int.astype(np.int)
# Out:
# 23/23 [==============================] - 0s 10ms/step
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# accuracy on validation set
print('Accuracy on validation set:', accuracy_score(y_valid,prediction_int), '%')
# Out:
# Accuracy on validation set: 0.6940509915014165 %

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### 4. Increasing number of epochs

# %%
# increase number of epochs
model=Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])

# %%
# model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               15052900
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 15,053,001
# Trainable params: 15,053,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history = model.fit(X_train, y_train, epochs=100, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/100
# 13/13 [==============================] - 4s 165ms/step - loss: 0.8180 - accuracy: 0.5826 - val_loss: 0.6489 - val_accuracy: 0.5949
# Epoch 2/100
# 13/13 [==============================] - 1s 84ms/step - loss: 0.6485 - accuracy: 0.6154 - val_loss: 0.6437 - val_accuracy: 0.6034
# Epoch 3/100
# 13/13 [==============================] - 1s 74ms/step - loss: 0.6326 - accuracy: 0.6440 - val_loss: 0.6376 - val_accuracy: 0.6317
# Epoch 4/100
# 13/13 [==============================] - 1s 72ms/step - loss: 0.6231 - accuracy: 0.6580 - val_loss: 0.6334 - val_accuracy: 0.6374
# Epoch 5/100
# 13/13 [==============================] - 1s 87ms/step - loss: 0.6235 - accuracy: 0.6440 - val_loss: 0.6321 - val_accuracy: 0.6431
# Epoch 6/100
# 13/13 [==============================] - 1s 84ms/step - loss: 0.5911 - accuracy: 0.7066 - val_loss: 0.5858 - val_accuracy: 0.6955
# Epoch 7/100
# 13/13 [==============================] - 1s 79ms/step - loss: 0.5946 - accuracy: 0.6865 - val_loss: 0.5868 - val_accuracy: 0.6997
# Epoch 8/100
# 13/13 [==============================] - 1s 86ms/step - loss: 0.5988 - accuracy: 0.6896 - val_loss: 0.5799 - val_accuracy: 0.6997
# Epoch 9/100
# 13/13 [==============================] - 1s 79ms/step - loss: 0.5855 - accuracy: 0.6944 - val_loss: 0.5781 - val_accuracy: 0.6955
# Epoch 10/100
# 13/13 [==============================] - 1s 113ms/step - loss: 0.5784 - accuracy: 0.6962 - val_loss: 0.6667 - val_accuracy: 0.6161
# Epoch 11/100
# 13/13 [==============================] - 1s 118ms/step - loss: 0.5684 - accuracy: 0.7108 - val_loss: 0.6396 - val_accuracy: 0.6346
# Epoch 12/100
# 13/13 [==============================] - 2s 133ms/step - loss: 0.5540 - accuracy: 0.7254 - val_loss: 0.5634 - val_accuracy: 0.7011
# Epoch 13/100
# 13/13 [==============================] - 1s 97ms/step - loss: 0.5812 - accuracy: 0.6981 - val_loss: 0.5682 - val_accuracy: 0.6955
# Epoch 14/100
# 13/13 [==============================] - 1s 76ms/step - loss: 0.5444 - accuracy: 0.7461 - val_loss: 0.5603 - val_accuracy: 0.7011
# Epoch 15/100
# 13/13 [==============================] - 1s 75ms/step - loss: 0.5578 - accuracy: 0.7199 - val_loss: 0.7497 - val_accuracy: 0.5892
# Epoch 16/100
# 13/13 [==============================] - 1s 88ms/step - loss: 0.5584 - accuracy: 0.7169 - val_loss: 0.5636 - val_accuracy: 0.7025
# Epoch 17/100
# 13/13 [==============================] - 1s 91ms/step - loss: 0.5347 - accuracy: 0.7509 - val_loss: 0.5679 - val_accuracy: 0.6955
# 13/13 [==============================] - 1s 62ms/step - loss: 0.3817 - accuracy: 0.8408 - val_loss: 0.5595 - val_accuracy: 0.7153
# Epoch 97/100
# 13/13 [==============================] - 1s 64ms/step - loss: 0.3334 - accuracy: 0.8633 - val_loss: 0.5760 - val_accuracy: 0.7139
# Epoch 98/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.3064 - accuracy: 0.8919 - val_loss: 0.5162 - val_accuracy: 0.7380
# Epoch 99/100
# 13/13 [==============================] - 1s 64ms/step - loss: 0.3727 - accuracy: 0.8293 - val_loss: 0.7081 - val_accuracy: 0.6586
# Epoch 100/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.3959 - accuracy: 0.8098 - val_loss: 0.5465 - val_accuracy: 0.7266

# %%
# getting predictions in the form of class as well as probabilities

predictions = model.predict(X_valid)[:, 0]
prediction = predictions.reshape(-1,)

# converting probabilities to classes
prediction_int = prediction >= 0.5
prediction_int = prediction_int.astype(np.int)
# Out:
# 23/23 [==============================] - 0s 10ms/step
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# accuracy on validation set
print('Accuracy on validation set:', accuracy_score(y_valid, prediction_int), '%')
# Out:
# Accuracy on validation set: 0.726628895184136 %

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### 5. Changing the optimizer

# %%
# importing adam optimizer from keras optimizer module 
from keras.optimizers import Adam

# %%
# defining the adam optimizer and setting the learning rate as 10^-5
adam = Adam(lr=1e-5)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# change optimizer
model=Sequential()

model.add(InputLayer(input_shape=(224*224*3,)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
# model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 100)               15052900
#
#  dense_3 (Dense)             (None, 100)               10100
#
#  dense_4 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 15,063,101
# Trainable params: 15,063,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history = model.fit(X_train, y_train, epochs=100, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/100
# 13/13 [==============================] - 2s 117ms/step - loss: 0.6660 - accuracy: 0.5948 - val_loss: 0.6589 - val_accuracy: 0.5694
# Epoch 2/100
# 13/13 [==============================] - 1s 65ms/step - loss: 0.6385 - accuracy: 0.6349 - val_loss: 0.6355 - val_accuracy: 0.6431
# Epoch 3/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.6241 - accuracy: 0.6665 - val_loss: 0.6215 - val_accuracy: 0.6586
# Epoch 4/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.6123 - accuracy: 0.6731 - val_loss: 0.6141 - val_accuracy: 0.6657
# Epoch 5/100
# 13/13 [==============================] - 1s 64ms/step - loss: 0.6037 - accuracy: 0.6883 - val_loss: 0.6076 - val_accuracy: 0.6742
# Epoch 6/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.5965 - accuracy: 0.7096 - val_loss: 0.6118 - val_accuracy: 0.6657
# 13/13 [==============================] - 1s 61ms/step - loss: 0.3632 - accuracy: 0.8919 - val_loss: 0.5303 - val_accuracy: 0.7365
# Epoch 86/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.3587 - accuracy: 0.8998 - val_loss: 0.5335 - val_accuracy: 0.7295
# Epoch 87/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.3561 - accuracy: 0.8979 - val_loss: 0.5450 - val_accuracy: 0.7195
# Epoch 88/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.3534 - accuracy: 0.9010 - val_loss: 0.5520 - val_accuracy: 0.7210
# Epoch 89/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.3524 - accuracy: 0.9052 - val_loss: 0.5533 - val_accuracy: 0.7266
# Epoch 90/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.3492 - accuracy: 0.9028 - val_loss: 0.5457 - val_accuracy: 0.7195
# Epoch 91/100
# 13/13 [==============================] - 1s 65ms/step - loss: 0.3475 - accuracy: 0.9028 - val_loss: 0.5448 - val_accuracy: 0.7181
# Epoch 92/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.3446 - accuracy: 0.9040 - val_loss: 0.5324 - val_accuracy: 0.7266
# Epoch 93/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.3420 - accuracy: 0.9064 - val_loss: 0.5306 - val_accuracy: 0.7323
# Epoch 94/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.3419 - accuracy: 0.9058 - val_loss: 0.5411 - val_accuracy: 0.7181
# Epoch 95/100
# 13/13 [==============================] - 1s 78ms/step - loss: 0.3370 - accuracy: 0.9089 - val_loss: 0.5455 - val_accuracy: 0.7224
# Epoch 96/100
# 13/13 [==============================] - 1s 80ms/step - loss: 0.3354 - accuracy: 0.9131 - val_loss: 0.5301 - val_accuracy: 0.7309
# Epoch 97/100
# 13/13 [==============================] - 1s 80ms/step - loss: 0.3391 - accuracy: 0.9010 - val_loss: 0.5251 - val_accuracy: 0.7365
# Epoch 98/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.3391 - accuracy: 0.9022 - val_loss: 0.5512 - val_accuracy: 0.7238
# Epoch 99/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.3275 - accuracy: 0.9162 - val_loss: 0.5324 - val_accuracy: 0.7224
# Epoch 100/100
# 13/13 [==============================] - 1s 65ms/step - loss: 0.3243 - accuracy: 0.9180 - val_loss: 0.5352 - val_accuracy: 0.7181

# %%
# getting predictions in the form of class as well as probabilities

predictions = model.predict(X_valid)[:, 0]
prediction = predictions.reshape(-1,)

# converting probabilities to classes
prediction_int = prediction >= 0.5
prediction_int = prediction_int.astype(np.int)
# Out:
# 23/23 [==============================] - 0s 11ms/step
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# accuracy on validation set
print('Accuracy on validation set:', accuracy_score(y_valid, prediction_int), '%')
# Out:
# Accuracy on validation set: 0.7181303116147308 %

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
